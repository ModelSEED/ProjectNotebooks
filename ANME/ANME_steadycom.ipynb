# %% [markdown]
# # load the models

# %%
# define the environment path 
import os
local_cobrakbase_path = os.path.join('C:', 'Users', 'Andrew Freiburger','Documents','Argonne','cobrakbase')
os.environ["HOME"] = local_cobrakbase_path

# import the KBase
import cobrakbase
# with open("/Users/afreiburger/Documents/kbase_token.txt") as token_file:
with open("C:/Users/Andrew Freiburger/Documents/Argonne/kbase_token.txt") as token_file:
    kbase_api = cobrakbase.KBaseAPI(token_file.readline())

# prevent excessive warnings
from time import process_time
import warnings
warnings.filterwarnings(action='once')


from pandas import set_option
# set_option("display.max_rows", None)
set_option("display.max_columns", None)
# Out:
# cobrakbase 0.3.1

# %%
srb_2a_model = kbase_api.get_from_ws("2a-srb",108554)
SeepSRB1a_2c_model = kbase_api.get_from_ws("2c-SeepSRB1a",108554)
srb_2c_model = kbase_api.get_from_ws("2c-srb",108554)
SeepSRB1a_2a_model = kbase_api.get_from_ws("2a-SeepSRB1a",108554)

# %% [markdown]
# # simulate the communities

# %%
# %run ../../ModelSEED/ModelSEEDpy/modelseedpy/community/mscommunity.py
# %run ../../ModelSEED/ModelSEEDpy/modelseedpy/community/mssteadycom.py

flux_threshold = None
ignore_mets = []
visualize = True
srb_2a_cross_feeding_df, srb_2a_exMets_df = MSSteadyCom.compute(MSCommunity(srb_2a_model), flux_threshold=flux_threshold, ignore_mets=ignore_mets, visualize=visualize)
display(srb_2a_cross_feeding_df, srb_2a_exMets_df)
print("\n\n")
SeepSRB1a_2c_cross_feeding_df, SeepSRB1a_2c_exMets_df = MSSteadyCom.compute(MSCommunity(SeepSRB1a_2c_model), flux_threshold=flux_threshold, ignore_mets=ignore_mets, visualize=visualize)
display(SeepSRB1a_2c_cross_feeding_df, SeepSRB1a_2c_exMets_df)
print("\n\n")
srb_2c_cross_feeding_df, srb_2c_exMets_df = MSSteadyCom.compute(MSCommunity(srb_2c_model), flux_threshold=flux_threshold, ignore_mets=ignore_mets, visualize=visualize)
display(srb_2c_cross_feeding_df, srb_2c_exMets_df)
print("\n\n")
SeepSRB1a_2a_cross_feeding_df, SeepSRB1a_2a_exMets_df = MSSteadyCom.compute(MSCommunity(SeepSRB1a_2a_model), flux_threshold=flux_threshold, ignore_mets=ignore_mets, visualize=visualize)
display(SeepSRB1a_2a_cross_feeding_df, SeepSRB1a_2a_exMets_df)
# Out:
# ic| mssteadycom.py:107 in compute()- individual.id: 'Species1'
# cpd11416_c0
# bio1: 0.5 cpd11416_c1 + 0.5 cpd11416_c2 --> cpd11416_c0
# primary biomass defined bio1: 0.5 cpd11416_c1 + 0.5 cpd11416_c2 --> cpd11416_c0
# SK_cpd11416_c0: cpd11416_c0 -->
# cpd11416_c1
# cpd11416_c2
# cpd11416_c1
# c1
# cpd11416_c2
# c2
# ic| mssteadycom.py:124 in compute()
#     normalized_flux: 61.791518284773666
# ic| mssteadycom.py:107 in compute()- individual.id: 'Species1'
# ic| mssteadycom.py:124 in compute()
#     normalized_flux: 44.02228897429457
# ic| mssteadycom.py:107 in compute()- individual.id: 'Species1'
# ic| mssteadycom.py:124 in compute()
#     normalized_flux: 73.07161981294391
# ic| mssteadycom.py:107 in compute()- individual.id: 'Species1'
# ic| mssteadycom.py:124 in compute()
#     normalized_flux: 100.00000000000148
# ic| mssteadycom.py:107 in compute()- individual.id: 'Species1'
# ic| mssteadycom.py:124 in compute()
#     normalized_flux: 0.2359833488974148
# ic| mssteadycom.py:107 in compute()- individual.id: 'Species1'
# ic| mssteadycom.py:124 in compute()- normalized_flux: 100.0
# ic| mssteadycom.py:107 in compute()- individual.id: 'Species1'
# ic| mssteadycom.py:124 in compute()
#     normalized_flux: 0.022953419788787795
#                      Environment    Species1  Species2
# Metabolite/Donor ID
# cpd00001_e0          -100.000000  100.000000       0.0
# cpd00006_e0             0.068860   -0.068860       0.0
# cpd00007_e0            56.702036  -56.702036       0.0
# cpd00010_e0             0.045907   -0.045907       0.0
# cpd00011_e0           -73.071620   73.071620       0.0
# ...                          ...         ...       ...
# cpd10515_e0           -44.022289   44.022289       0.0
# cpd10516_e0            44.091149  -44.091149       0.0
# cpd15311_e0             1.019033   -1.019033       0.0
# zz_Environment          0.000000  184.279242       0.0
# zz_Species1           379.144364    0.000000       0.0
#
# [76 rows x 3 columns]
#                                           Environment  \
# Donor ID
# Environment
# Species1     Acetate; Fe2+; CO2; H+; PPi; H2O; Niacin
# Species2
#
#                                                       Species1 Species2
# Donor ID
# Environment  Deoxyguanosine; D-Arabinose; BIOT; L-Serine; L...
# Species1
# Species2
# cpd11416_c0
# bio1: 0.5 cpd11416_c1 + 0.5 cpd11416_c2 --> cpd11416_c0
# primary biomass defined bio1: 0.5 cpd11416_c1 + 0.5 cpd11416_c2 --> cpd11416_c0
# SK_cpd11416_c0: cpd11416_c0 -->
# cpd11416_c1
# cpd11416_c2
# cpd11416_c1
# c1
# cpd11416_c2
# c2
# ic| mssteadycom.py:107 in compute()- individual.id: 'Species1'
# ic| mssteadycom.py:124 in compute()
#     normalized_flux: 47.52042466870089
# ic| mssteadycom.py:107 in compute()- individual.id: 'Species2'
# ic| mssteadycom.py:124 in compute()
#     normalized_flux: 14.273024644263028
# ic| mssteadycom.py:107 in compute()- individual.id: 'Species2'
# ic| mssteadycom.py:124 in compute()
#     normalized_flux: 44.04247604515447
# ic| mssteadycom.py:107 in compute()- individual.id: 'Species1'
# ic| mssteadycom.py:124 in compute()
#     normalized_flux: 58.797632747318495
# ic| mssteadycom.py:107 in compute()- individual.id: 'Species2'
# ic| mssteadycom.py:124 in compute()
#     normalized_flux: 14.27302464426303
# ic| mssteadycom.py:107 in compute()- individual.id: 'Species1'
# ic| mssteadycom.py:124 in compute()
#     normalized_flux: 41.684499310585764
# ic| mssteadycom.py:107 in compute()- individual.id: 'Species2'
# ic| mssteadycom.py:124 in compute()
#     normalized_flux: 58.31550068941759
# ic| mssteadycom.py:107 in compute()- individual.id: 'Species1'
# ic| mssteadycom.py:124 in compute()
#     normalized_flux: 0.21228086958686807
# ic| mssteadycom.py:107 in compute()- individual.id: 'Species1'
# ic| mssteadycom.py:124 in compute()
#     normalized_flux: 100.00000000000001
# ic| mssteadycom.py:107 in compute()- individual.id: 'Species1'
# ic| mssteadycom.py:124 in compute()
#     normalized_flux: 0.022947532025982265
#                      Environment    Species1      Species2
# Metabolite/Donor ID
# cpd00001_e0          -100.000000  107.748213 -7.748213e+00
# cpd00006_e0             0.068843   -0.068843  0.000000e+00
# cpd00007_e0            56.697402  -53.434997 -3.262406e+00
# cpd00010_e0             0.045895   -0.045895 -1.803996e-15
# cpd00011_e0           -73.070657   58.797633  1.427302e+01
# ...                          ...         ...           ...
# cpd10516_e0            44.111319   -0.068843 -4.404248e+01
# cpd15311_e0             1.018772   -1.018772  0.000000e+00
# zz_Environment          0.000000  129.840827  5.444139e+01
# zz_Species1           248.237785    0.000000  0.000000e+00
# zz_Species2           130.904026    7.748213  0.000000e+00
#
# [77 rows x 3 columns]
#                                     Environment  \
# Donor ID
# Environment
# Species1     Acetate; CO2; H+; PPi; H2O; Niacin
# Species2                 Acetate; Fe2+; CO2; H+
#
#                                                       Species1  \
# Donor ID
# Environment  Deoxyguanosine; D-Arabinose; BIOT; L-Serine; L...
# Species1
# Species2                                              PPi; H2O
#
#                                  Species2
# Donor ID
# Environment  D-Glucose; O2; fe3; CoA; AMP
# Species1
# Species2
# cpd11416_c0
# bio1: 0.5 cpd11416_c1 + 0.5 cpd11416_c2 --> cpd11416_c0
# primary biomass defined bio1: 0.5 cpd11416_c1 + 0.5 cpd11416_c2 --> cpd11416_c0
# SK_cpd11416_c0: cpd11416_c0 -->
# cpd11416_c1
# cpd11416_c2
# cpd11416_c1
# c1
# cpd11416_c2
# c2
# ic| mssteadycom.py:107 in compute()- individual.id: 'Species1'
# ic| mssteadycom.py:124 in compute()
#     normalized_flux: 46.98394229568424
# ic| mssteadycom.py:107 in compute()- individual.id: 'Species2'
# ic| mssteadycom.py:124 in compute()
#     normalized_flux: 15.240840304392693
# ic| mssteadycom.py:107 in compute()- individual.id: 'Species2'
# ic| mssteadycom.py:124 in compute()
#     normalized_flux: 43.54525801255054
# ic| mssteadycom.py:107 in compute()- individual.id: 'Species1'
# ic| mssteadycom.py:124 in compute()
#     normalized_flux: 58.13383620585327
# ic| mssteadycom.py:107 in compute()- individual.id: 'Species2'
# ic| mssteadycom.py:124 in compute()
#     normalized_flux: 15.24084030439269
# ic| mssteadycom.py:107 in compute()- individual.id: 'Species1'
# ic| mssteadycom.py:124 in compute()
#     normalized_flux: 41.213901683059774
# ic| mssteadycom.py:107 in compute()- individual.id: 'Species2'
# ic| mssteadycom.py:124 in compute()
#     normalized_flux: 58.78609831694321
# ic| mssteadycom.py:107 in compute()- individual.id: 'Species1'
# ic| mssteadycom.py:124 in compute()
#     normalized_flux: 0.20988432230360213
# ic| mssteadycom.py:107 in compute()- individual.id: 'Species1'
# ic| mssteadycom.py:124 in compute()- normalized_flux: 100.0
# ic| mssteadycom.py:107 in compute()- individual.id: 'Species1'
# ic| mssteadycom.py:124 in compute()
#     normalized_flux: 0.022688465603028358
# ic| mssteadycom.py:107 in compute()- individual.id: 'Species2'
#                      Environment    Species1      Species2
# Metabolite/Donor ID
# cpd00001_e0          -100.000000  106.531789 -6.531789e+00
# cpd00006_e0             0.068065   -0.068065  0.000000e+00
# cpd00007_e0            57.186267  -52.831742 -4.354526e+00
# cpd00010_e0             0.045377   -0.045377 -1.803996e-15
# cpd00011_e0           -73.374677   58.133836  1.524084e+01
# ...                          ...         ...           ...
# cpd10516_e0            43.613323   -0.068065 -4.354526e+01
# cpd15311_e0             1.007270   -1.007270  0.000000e+00
# zz_Environment          0.000000  128.374987  5.552020e+01
# zz_Species1           246.564253    0.000000  4.061299e-15
# zz_Species2           132.813037    6.531789  0.000000e+00
#
# [77 rows x 3 columns]
#                                     Environment  \
# Donor ID
# Environment
# Species1     Acetate; CO2; H+; PPi; H2O; Niacin
# Species2                 Acetate; Fe2+; CO2; H+
#
#                                                       Species1  \
# Donor ID
# Environment  Deoxyguanosine; D-Arabinose; BIOT; L-Serine; L...
# Species1
# Species2                                                   H2O
#
#                             Species2
# Donor ID
# Environment  D-Glucose; O2; fe3; CoA
# Species1                         AMP
# Species2
# cpd11416_c0
# bio1: 0.5 cpd11416_c1 + 0.5 cpd11416_c2 --> cpd11416_c0
# primary biomass defined bio1: 0.5 cpd11416_c1 + 0.5 cpd11416_c2 --> cpd11416_c0
# SK_cpd11416_c0: cpd11416_c0 -->
# cpd11416_c1
# cpd11416_c2
# cpd11416_c1
# c1
# cpd11416_c2
# c2
# ic| mssteadycom.py:107 in compute()- individual.id: 'Species1'
# ic| mssteadycom.py:124 in compute()
#     normalized_flux: 61.79151828477409
# ic| mssteadycom.py:107 in compute()- individual.id: 'Species1'
# ic| mssteadycom.py:124 in compute()
#     normalized_flux: 44.02228897429558
# ic| mssteadycom.py:107 in compute()- individual.id: 'Species1'
# ic| mssteadycom.py:124 in compute()
#     normalized_flux: 73.07161981294436
# ic| mssteadycom.py:107 in compute()- individual.id: 'Species1'
# ic| mssteadycom.py:124 in compute()
#     normalized_flux: 100.00000000000247
# ic| mssteadycom.py:107 in compute()- individual.id: 'Species2'
# ic| mssteadycom.py:107 in compute()- individual.id: 'Species2'
# ic| mssteadycom.py:107 in compute()- individual.id: 'Species2'
# ic| mssteadycom.py:107 in compute()- individual.id: 'Species1'
# ic| mssteadycom.py:124 in compute()
#     normalized_flux: 0.23598334889712383
# ic| mssteadycom.py:107 in compute()- individual.id: 'Species1'
# ic| mssteadycom.py:124 in compute()- normalized_flux: 100.0
# ic| mssteadycom.py:107 in compute()- individual.id: 'Species2'
# ic| mssteadycom.py:124 in compute()
#     normalized_flux: 1.6509580172774606e-15
# ic| mssteadycom.py:107 in compute()- individual.id: 'Species1'
# ic| mssteadycom.py:124 in compute()
#     normalized_flux: 0.022953419788787805
# ic| mssteadycom.py:107 in compute()- individual.id: 'Species2'
#                       Environment      Species1      Species2
# Metabolite/Donor ID
# cpd00001_e0         -1.000000e+02  1.000000e+02  1.650958e-15
# cpd00006_e0          6.886026e-02 -6.886026e-02  0.000000e+00
# cpd00007_e0          5.670204e+01 -5.670204e+01  6.951402e-16
# cpd00010_e0          4.590684e-02 -4.590684e-02  0.000000e+00
# cpd00011_e0         -7.307162e+01  7.307162e+01 -3.041238e-15
# ...                           ...           ...           ...
# cpd10516_e0          4.409115e+01 -4.409115e+01  9.384393e-15
# cpd15311_e0          1.019033e+00 -1.019033e+00  0.000000e+00
# zz_Environment       0.000000e+00  1.842792e+02  0.000000e+00
# zz_Species1          3.791444e+02  0.000000e+00  1.160015e-14
# zz_Species2          1.650958e-15  1.850811e-14  0.000000e+00
#
# [77 rows x 3 columns]
#                                           Environment  \
# Donor ID
# Environment
# Species1     Acetate; Fe2+; CO2; H+; PPi; H2O; Niacin
# Species2                                          H2O
#
#                                                       Species1  \
# Donor ID
# Environment  Deoxyguanosine; D-Arabinose; BIOT; L-Serine; L...
# Species1
# Species2                                 Acetate; CO2; H+; PPi
#
#                             Species2
# Donor ID
# Environment
# Species1     D-Glucose; O2; fe3; AMP
# Species2

# %% [markdown]
# #### The total ANME community

# %%
all_anme_model = kbase_api.get_from_ws("all_anme",108554)
all_anme_cross_feeding_df, all_anme_exMets_df = MSSteadyCom.compute(MSCommunity(all_anme_model), flux_threshold=flux_threshold, ignore_mets=ignore_mets, visualize=visualize)
display(all_anme_cross_feeding_df, all_anme_exMets_df)
# Out:
# cpd11416_c0
# bio1: 0.25 cpd11416_c1 + 0.25 cpd11416_c2 + 0.25 cpd11416_c3 + 0.25 cpd11416_c4 --> cpd11416_c0
# primary biomass defined bio1: 0.25 cpd11416_c1 + 0.25 cpd11416_c2 + 0.25 cpd11416_c3 + 0.25 cpd11416_c4 --> cpd11416_c0
# SK_cpd11416_c0: cpd11416_c0 -->
# cpd11416_c1
# cpd11416_c2
# cpd11416_c3
# cpd11416_c4
# cpd11416_c1
# c1
# cpd11416_c2
# c2
# cpd11416_c3
# c3
# cpd11416_c4
# c4
# ic| mssteadycom.py:107 in compute()- individual.id: 'Species3'
# ic| mssteadycom.py:124 in compute()
#     normalized_flux: 47.520424668700684
# ic| mssteadycom.py:107 in compute()- individual.id: 'Species4'
# ic| mssteadycom.py:124 in compute()
#     normalized_flux: 14.273024644262827
# ic| mssteadycom.py:107 in compute()- individual.id: 'Species4'
# ic| mssteadycom.py:124 in compute()
#     normalized_flux: 44.04247604515386
# ic| mssteadycom.py:107 in compute()- individual.id: 'Species3'
# ic| mssteadycom.py:124 in compute()
#     normalized_flux: 58.797632747318225
# ic| mssteadycom.py:107 in compute()- individual.id: 'Species4'
# ic| mssteadycom.py:124 in compute()
#     normalized_flux: 14.273024644262824
# ic| mssteadycom.py:107 in compute()- individual.id: 'Species3'
# ic| mssteadycom.py:124 in compute()
#     normalized_flux: 41.68449931058541
# ic| mssteadycom.py:107 in compute()- individual.id: 'Species4'
# ic| mssteadycom.py:124 in compute()
#     normalized_flux: 58.315500689416645
# ic| mssteadycom.py:107 in compute()- individual.id: 'Species3'
# ic| mssteadycom.py:124 in compute()
#     normalized_flux: 0.21228086958688766
# ic| mssteadycom.py:107 in compute()- individual.id: 'Species1'
# ic| mssteadycom.py:124 in compute()
#     normalized_flux: 1.6147229815287132e-13
# ic| mssteadycom.py:107 in compute()- individual.id: 'Species3'
# ic| mssteadycom.py:124 in compute()
#     normalized_flux: 99.99999999999984
# ic| mssteadycom.py:107 in compute()- individual.id: 'Species3'
# ic| mssteadycom.py:124 in compute()
#     normalized_flux: 0.022947532025982167
# ic| mssteadycom.py:107 in compute()- individual.id: 'Species4'
# C:\Users\Andrew Freiburger\AppData\Local\Programs\Python\Python39\lib\site-packages\sigfig\sigfig.py:586: UserWarning: warning: 3 significant figures requested from number with only 1 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))
#                       Environment      Species1  Species2    Species3  \
# Metabolite/Donor ID
# cpd00001_e0         -1.000000e+02  1.739835e-13       0.0  107.748213
# cpd00006_e0          6.884260e-02  0.000000e+00       0.0   -0.068843
# cpd00007_e0          5.669740e+01  0.000000e+00       0.0  -53.434997
# cpd00010_e0          4.589506e-02  0.000000e+00       0.0   -0.045895
# cpd00011_e0         -7.307066e+01  0.000000e+00       0.0   58.797633
# ...                           ...           ...       ...         ...
# cpd15311_e0          1.018772e+00  0.000000e+00       0.0   -1.018772
# zz_Environment       0.000000e+00  0.000000e+00       0.0  129.840827
# zz_Species1          1.614723e-13  0.000000e+00       0.0    0.000000
# zz_Species3          2.482378e+02  0.000000e+00       0.0    0.000000
# zz_Species4          1.309040e+02  1.251122e-14       0.0    7.748213
#
#                          Species4
# Metabolite/Donor ID
# cpd00001_e0         -7.748213e+00
# cpd00006_e0          0.000000e+00
# cpd00007_e0         -3.262406e+00
# cpd00010_e0          0.000000e+00
# cpd00011_e0          1.427302e+01
# ...                           ...
# cpd15311_e0          0.000000e+00
# zz_Environment       5.444139e+01
# zz_Species1          0.000000e+00
# zz_Species3          2.953672e-15
# zz_Species4          0.000000e+00
#
# [78 rows x 5 columns]
#                                     Environment Species1 Species2  \
# Donor ID
# Environment
# Species1                                    H2O
# Species2
# Species3     Acetate; CO2; H+; PPi; H2O; Niacin
# Species4                 Acetate; Fe2+; CO2; H+      H2O
#
#                                                       Species3  \
# Donor ID
# Environment  Deoxyguanosine; D-Arabinose; BIOT; L-Serine; L...
# Species1
# Species2
# Species3
# Species4                                                   H2O
#
#                        Species4
# Donor ID
# Environment  D-Glucose; O2; fe3
# Species1
# Species2
# Species3                    AMP
# Species4

# %%
print(sorted(["a", "b,", "z", "_"]))
# Out:
# ['_', 'a', 'b,', 'z']

# %%
print("asdf".split("_"))

# %%
sol = srb_2a_model.optimize()
print(sol.fluxes)
# Out:
# rxn05319_c1      -100.000000
# rxn05209_c1         0.000000
# rxn05468_c1        56.702036
# rxn05467_c1       -73.071620
# rxn07191_c1       -69.946760
# rxn05226_c1        36.459995
# rxn00459_c1        70.673259
# rxn00148_c1       -32.797692
# rxn01100_c1      -140.620019
# rxn14418_c1       113.289304
# rxn00781_c1       140.620019
# rxn00172_c1       -61.382362
# rxn00558_c1        36.406094
# rxn10122_c1       113.289304
# rxn05488_c1       -61.791518
# rxn01106_c1       -70.673259
# rxn05938_c1       -69.900853
# rxn08173_c1       193.820688
# rxn00786_c1        35.200244
# rxn00545_c1        35.200244
# rxn14419_c1       113.289304
# rxn00747_c1       -35.200244
# rxn13783_c1         8.179657
# rxn04384_c1         0.000000
# rxn05064_c1         0.000000
# rxn02374_c1         0.000000
# rxn05555_c1         0.000000
# rxn04457_c1         0.000000
# rxn02916_c1         0.000000
# rxn03012_c1         0.000000
# rxn08924_c1         0.022953
# rxn08475_c1        44.022289
# rxn04132_c1         0.000000
# rxn11544_c1         0.000000
# rxn05195_c1        44.091149
# rxn01208_c1         0.000000
# rxn02989_c1         0.000000
# rxn04791_c1         0.000000
# rxn06979_c1         0.000000
# rxn01101_c1         0.000000
# rxn01790_c1         0.000000
# rxn05596_c1        -0.045907
# rxn04133_c1         0.000000
# rxn05054_c1         0.000000
# rxn10570_c1         0.000000
# rxn24718_c1         0.000000
# rxn23589_c1         0.000000
# rxn08502_c1         0.000000
# rxn05508_c1         1.642727
# rxn05582_c1         4.101700
# rxn05255_c1         0.068860
# rxn05663_c1         0.386096
# rxn05303_c1         2.017895
# rxn05217_c1         1.642727
# rxn05301_c1         0.987093
# rxn05244_c1         1.977829
# rxn08192_c1         0.000000
# rxn05307_c1         1.745603
# rxn05243_c1         3.070552
# rxn05645_c1         0.068860
# rxn05308_c1         0.000000
# rxn09693_c1         0.022953
# rxn05638_c1         1.507958
# rxn05652_c1        -0.022953
# EX_cpd00129_e0     -1.507958
# EX_cpd00007_e0    -56.702036
# EX_cpd00066_e0     -1.263916
# EX_cpd00393_e0     -0.068860
# EX_cpd00357_e0     -0.141612
# EX_cpd00794_e0     -0.484495
# EX_cpd00205_e0     -0.022953
# EX_cpd00084_e0     -0.622852
# EX_cpd00644_e0      0.000000
# EX_cpd00635_e0      0.000000
# EX_cpd00111_e0     -0.011477
# EX_cpd01157_e0      0.000000
# EX_cpd00038_e0     -1.107581
# EX_cpd00322_e0     -1.977829
# EX_cpd00027_e0    -36.459995
# EX_cpd00100_e0     -0.509516
# EX_cpd00105_e0      0.000000
# EX_cpd00091_e0     -0.765927
# EX_cpd00099_e0     -0.022953
# EX_cpd10516_e0    -44.091149
# EX_cpd00001_e0    100.000000
# EX_cpd03847_e0     -1.022891
# EX_cpd00185_e0     -0.613734
# EX_cpd00149_e0     -0.022953
# EX_cpd00122_e0     -0.726499
# EX_cpd00156_e0     -2.881147
# EX_cpd01741_e0     -0.204578
# EX_cpd00138_e0      0.000000
# EX_cpd00731_e0     -0.204578
# EX_cpd00305_e0     -0.022953
# EX_cpd00161_e0     -1.726503
# EX_cpd00136_e0     -0.022953
# EX_cpd00241_e0     -0.097533
# EX_cpd00009_e0      0.000000
# EX_cpd00338_e0     -0.183627
# EX_cpd00058_e0     -0.022953
# EX_cpd00104_e0     -0.022953
# EX_cpd00047_e0     -0.022953
# EX_cpd00010_e0     -0.045907
# EX_cpd00006_e0     -0.068860
# EX_cpd00069_e0     -0.987093
# EX_cpd00215_e0     -0.022953
# EX_cpd00107_e0     -3.070552
# EX_cpd00264_e0     -0.022953
# EX_cpd00012_e0      0.235983
# EX_cpd00654_e0     -0.120487
# EX_cpd00277_e0     -0.022953
# EX_cpd00116_e0      0.000000
# EX_cpd00041_e0     -1.642727
# EX_cpd00118_e0     -0.022953
# EX_cpd00046_e0     -0.687939
# EX_cpd10515_e0     44.022289
# EX_cpd00115_e0     -0.141612
# EX_cpd00089_e0      0.000000
# EX_cpd00065_e0     -0.386096
# EX_cpd00540_e0     -0.045907
# EX_cpd00067_e0    100.000000
# SK_cpd11416_c0      0.000000
# rxn00062_c1         0.000000
# DM_cpd11416_c1      8.179657
# rxn00062_c2         0.000000
# DM_cpd11416_c2      0.000000
# Name: fluxes, dtype: float64

# %%
from modelseedpy.core.exceptions import ObjectAlreadyDefinedError, ParameterError, NoFluxError
from modelseedpy.community.commhelper import CommHelper
from itertools import combinations
from optlang.symbolics import Zero
from pandas import DataFrame
from matplotlib import pyplot
from numpy import array
import networkx
import sigfig
import os, re


def compute(
        mscommodel,                          # The MSCommunity object of the model (mandatory to prevent circular imports)
        models:list=None,                    # the list of models that will be assembled into a community
        solution = None,                     # the COBRA simulation solution that will be parsed and visualized
        media=None,                          # The media in which the community model will be simulated
        names=None, abundances=None,         # names and abundances of the community species
        flux_threshold: int = 1,             # The threshold of normalized flux below which a reaction is not plotted
        visualize: bool = True,              # specifies whether the net flux will be depicted in a network diagram
        filename: str = 'cross_feeding_diagram.svg',  # Cross-feeding figure export name
        export_directory: str = None,        # specifies the directory to which the network diagram and associated datatable will be exported, where None does not export the content
        node_metabolites: bool = True,       # specifies whether the metabolites of each node will be printed
        x_offset: float = 0.15,              # specifies the x-axis buffer between each species node and its metabolite list in the network diagram
        show_figure: bool = True,            # specifies whether the figure will be printed to the console
        ignore_mets=None                     # cross-fed exchanges that will not be displayed in the graphs
        ):
    # defining the models
    model = mscommodel.util.model if not models else CommHelper.build_from_species_models(
        models, names=names, abundances=abundances, cobra_model=True)

    #Check for solution
    solution = solution or mscommodel.run(media)
    print(solution.fluxes)
    if not solution:
        raise ParameterError("A solution must be provided. Interactions are computed from a solution.")
    if all(array(list(solution.fluxes.values)) == 0):
        print(list(solution.fluxes.values))
        raise NoFluxError("The simulation lacks any flux.")

    #Initialize data
    metabolite_data, species_data, species_collection = {}, {"Environment":{}}, {"Environment":{}}
    data = {"IDs":[],"Metabolites/Donor":[], "Environment":[]}
    met_list, species_list = [], [None]*1000

    #establish spreadsheet infrastructure for only extracellular metabolites
    for met in model.metabolites:
        if met.compartment == "e0":
            met_list.append(met)
            data["IDs"].append(met.id)
            data["Metabolites/Donor"].append(re.sub(r"(_\w\d$)", "", met.name))

            metabolite_data[met] = {}
            metabolite_data[met]["Environment"] = 0
            for individual in mscommodel.species:
                metabolite_data[met][individual.id] = 0

    for individual in mscommodel.species:
        species_data[individual.id], species_collection[individual.id] = {}, {}
        species_list[individual.index] = individual
        data[individual.id] = []
        for other in mscommodel.species:
            species_data[individual.id][other.id] = 0
            species_collection[individual.id][other.id] = []

        species_data["Environment"][individual.id] = species_data[individual.id]["Environment"] = 0
        species_collection["Environment"][individual.id], species_collection[individual.id]["Environment"] = [], []

    # computing net metabolite flux from each reaction
    for rxn in model.reactions:
        if rxn.id[0:3] == "EX_" and abs(solution.fluxes[rxn.id]) > Zero:
            cpd = list(rxn.metabolites.keys())[0]
            if cpd in metabolite_data:
                metabolite_data[cpd]["Environment"] += -solution.fluxes[rxn.id]
        if len(rxn.id.split("_")) > 1:
            comp_index = int(rxn.id.split("_")[-1][1:])
            for met in rxn.metabolites:
                if met in metabolite_data and species_list[comp_index]:
                    metabolite_data[met][species_list[comp_index].id] += solution.fluxes[rxn.id]*rxn.metabolites[met]

    # translating net metabolite flux into species interaction flux
    ignore_mets = ignore_mets or ["h2o_e0", "co2_e0"]
    for met in metabolite_data:
        #Iterating through the metabolite producers
        # !!! Why are fluxes normalized?
        total = sum([max([metabolite_data[met][individual.id], 0]) for individual in mscommodel.species])
        total += max([metabolite_data[met]["Environment"], 0])
        for individual in mscommodel.species:
            if metabolite_data[met][individual.id] <= Zero:
                continue
           ## calculate the total net flux between each combination of species, and track the involved metabolites
            for other in mscommodel.species:
                if metabolite_data[met][other.id] >= Zero:
                    continue
                # !!! Why is the flux product determined?
                normalized_flux = abs(metabolite_data[met][individual.id]*metabolite_data[met][other.id])/total
                species_data[individual.id][other.id] += normalized_flux
                if normalized_flux > flux_threshold and not any(
                        [re.search(x, met.name, flags=re.IGNORECASE) for x in ignore_mets]):
                    species_collection[individual.id][other.id].append(re.sub(r"(_\w\d$)", "", met.name))
            ## calculate the total out-flux from a species to the environment
            if metabolite_data[met]["Environment"] >= Zero:
                continue
            normalized_flux = abs(metabolite_data[met][individual.id]*metabolite_data[met]["Environment"])/total
            species_data[individual.id]["Environment"] += normalized_flux
            if normalized_flux > flux_threshold:
                species_collection[individual.id]["Environment"].append(re.sub(r"(_\w\d$)", "", met.name))
        if metabolite_data[met]["Environment"] <= Zero:
            continue
        ## calculate the total in-flux to a species from the environment
        for individual in mscommodel.species:
            if metabolite_data[met][individual.id] >= Zero:
                continue
            normalized_flux = abs(metabolite_data[met][individual.id]*metabolite_data[met]["Environment"])/total
            species_data["Environment"][individual.id] += normalized_flux
            if normalized_flux > flux_threshold:
                species_collection["Environment"][individual.id].append(re.sub(r"(_\w\d$)", "", met.name))

    # construct the dataframes
    for met in met_list:
        for individual in mscommodel.species:
            data[individual.id].append(metabolite_data[met][individual.id])
        data["Environment"].append(metabolite_data[met]["Environment"])

    ## process the fluxes dataframe
    data["IDs"].append("zzEnvironment")
    data["Metabolites/Donor"].append(0)
    print(mscommodel.species)
    for individual in mscommodel.species:
        data[individual.id].append(species_data["Environment"][individual.id])
    data["Environment"].append(0)
    for individual in mscommodel.species:
        for other in mscommodel.species:
            data[individual.id].append(species_data[individual.id][other.id])
        data["Environment"].append(species_data[individual.id]["Environment"])
        data["IDs"].append(f"zzSpecies{individual.index}")
        data["Metabolites/Donor"].append(individual.id)

    if len(set(list(map(len, list(data.values()))))) != 1:
        print([(col, len(content)) for col, content in data.items()])
    cross_feeding_df = DataFrame(data)
    cross_feeding_df.index = list(map(str, cross_feeding_df["IDs"])) # sorted()
    cross_feeding_df.index.name = "Metabolite/Donor ID"
    cross_feeding_df.drop(['IDs', "Metabolites/Donor"], axis=1, inplace=True)
    cross_feeding_df = cross_feeding_df.loc[(cross_feeding_df != 0).any(axis=1)]
    cross_feeding_df.sort_index(inplace=True)

    ## process the identities dataframe
    exchanged_mets = {"Environment":[" "], "Donor ID":["Environment"]}
    exchanged_mets.update({ind.id: [] for ind in mscommodel.species})
    for individual in mscommodel.species:
        ### environment exchanges
        exchanged_mets[individual.id].append("; ".join(species_collection["Environment"][individual.id]))
        exchanged_mets["Environment"].append("; ".join(species_collection[individual.id]["Environment"]))
        ### member exchanges
        exchanged_mets["Donor ID"].append(individual.id)
        for other in mscommodel.species:
            exchanged_mets[individual.id].append("; ".join(species_collection[individual.id][other.id]))

    if len(set(list(map(len, list(exchanged_mets.values()))))) != 1:
        print([(col, len(content)) for col, content in exchanged_mets.items()])
    exMets_df = DataFrame(exchanged_mets)
    exMets_df.index = list(map(str, exMets_df["Donor ID"]))
    exMets_df.index.name = "Donor ID"
    exMets_df.drop(["Donor ID"], axis=1, inplace=True)
    exMets_df.sort_index(inplace=True)
    exMets_df.fillna(" ")
    # logger.info(cross_feeding_df)

    # graph the network diagram
    if visualize:
        MSSteadyCom._visualize_cross_feeding(
            cross_feeding_df, exMets_df, filename, export_directory, mscommodel.species,
