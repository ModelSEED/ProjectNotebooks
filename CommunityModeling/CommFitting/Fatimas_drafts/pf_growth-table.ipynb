# %%
import cobrakbase
import pandas as pd
import cplex
import cobra

# %%
# kbase_api = cobrakbase.KBaseAPI()
# model1 = kbase_api.get_from_ws("iML1515",76994)
# model2 = kbase_api.get_from_ws("iSB1139.kb.gf",30650)
model1= cobra.io.load_json_model("Andrew/iML1515_5-17-22.json")
model2= cobra.io.load_json_model("Andrew/iSB1139.kb.gf_5-17-22.json")

model1.solver = 'optlang-cplex'
model2.solver = 'optlang-cplex'

# %%
# for rxn in model1.reactions:
#     if "EX" in rxn.id:
#         print (rxn.id, rxn.name)

# %%
for rxn in model1.reactions:
    if "bio" in rxn.id:
        print (rxn.id, rxn.name)
# Out:
# bio1 R_BIOMASS_Ec_iML1515_core_75p37M (E. coli biomass objective function (iML1515) - core - with 75.37 GAM estimate)
# bio2 R_BIOMASS_Ec_iML1515_WT_75p37M (E. coli biomass objective function (iML1515) - WT - with 75.37 GAM estimate)

# %%
medium = {
         'EX_cpd00048_e0':100,
         'EX_cpd00009_e0':100,
         'EX_cpd00030_e0': 100,
         'EX_cpd10515_e0': 100,
         'EX_cpd00971_e0': 100,
         'EX_cpd00254_e0': 100,
         'EX_cpd00013_e0': 100,
         'EX_cpd00205_e0': 100,
         'EX_cpd00007_e0': 20,
         'EX_cpd00001_e0': 100,
         'EX_cpd00067_e0': 100,
         'EX_cpd10516_e0': 100.0,
         'EX_cpd00034_e0': 100.0,
         'EX_cpd00063_e0': 100.0,
         'EX_cpd00244_e0': 100.0,
         'EX_cpd00058_e0': 100.0,
         'EX_cpd03396_e0': 100.0,
         'EX_cpd00149_e0': 100.0,
         'EX_cpd11574_e0': 100.0,
         'EX_cpd00099_e0': 100.0,
         'EX_cpd00635_e0':100,
         'EX_cpd15574_e0': 100.0,
         'EX_cpd03387_e0': 100.0
}
print(len(medium), sorted(list(medium.keys())))

medium2 = {
         'EX_cpd00048_e0':100,
         'EX_cpd00009_e0':100,
         'EX_cpd00030_e0': 100,
         'EX_cpd10515_e0': 100,
         'EX_cpd00971_e0': 100,
         'EX_cpd00254_e0': 100,
         'EX_cpd00013_e0': 100,
         'EX_cpd00205_e0': 100,
         'EX_cpd00007_e0': 20,
         'EX_cpd00001_e0': 100,
         'EX_cpd00067_e0': 100,
         'EX_cpd10516_e0': 100.0,
         'EX_cpd00034_e0': 100.0,
         'EX_cpd00063_e0': 100.0,
         #'EX_ni2_e': 100.0,
         #'EX_cu2_e': 100.0,
         #'EX_sel_e': 100.0,
         'EX_cpd00149_e0': 100.0,
         #'EX_mobd_e': 100.0,
         'EX_cpd00099_e0': 100.0,
         #'EX_cbl1_e':100,
         #'EX_tungs_e': 100.0,
         #'EX_slnt_e': 100.0
}
print(len(medium2), sorted(list(medium2.keys())))
# Out:
# 23 ['EX_cpd00001_e0', 'EX_cpd00007_e0', 'EX_cpd00009_e0', 'EX_cpd00013_e0', 'EX_cpd00030_e0', 'EX_cpd00034_e0', 'EX_cpd00048_e0', 'EX_cpd00058_e0', 'EX_cpd00063_e0', 'EX_cpd00067_e0', 'EX_cpd00099_e0', 'EX_cpd00149_e0', 'EX_cpd00205_e0', 'EX_cpd00244_e0', 'EX_cpd00254_e0', 'EX_cpd00635_e0', 'EX_cpd00971_e0', 'EX_cpd03387_e0', 'EX_cpd03396_e0', 'EX_cpd10515_e0', 'EX_cpd10516_e0', 'EX_cpd11574_e0', 'EX_cpd15574_e0']
# 16 ['EX_cpd00001_e0', 'EX_cpd00007_e0', 'EX_cpd00009_e0', 'EX_cpd00013_e0', 'EX_cpd00030_e0', 'EX_cpd00034_e0', 'EX_cpd00048_e0', 'EX_cpd00063_e0', 'EX_cpd00067_e0', 'EX_cpd00099_e0', 'EX_cpd00149_e0', 'EX_cpd00205_e0', 'EX_cpd00254_e0', 'EX_cpd00971_e0', 'EX_cpd10515_e0', 'EX_cpd10516_e0']

# %%
#ec
model1.solver = 'optlang-cplex'
medium = {
         'EX_cpd00048_e0':100,
         'EX_cpd00009_e0':100,
         'EX_cpd00030_e0': 100,
         'EX_cpd10515_e0': 100,
         'EX_cpd00971_e0': 100,
         'EX_cpd00254_e0': 100,
         'EX_cpd00013_e0': 100,
         'EX_cpd00205_e0': 100,
         'EX_cpd00007_e0': 20,
         'EX_cpd00001_e0': 100,
         'EX_cpd00067_e0': 100,
         'EX_cpd10516_e0': 100.0,
         'EX_cpd00034_e0': 100.0,
         'EX_cpd00063_e0': 100.0,
         'EX_cpd00244_e0': 100.0,
         'EX_cpd00058_e0': 100.0,
         'EX_cpd03396_e0': 100.0,
         'EX_cpd00149_e0': 100.0,
         'EX_cpd11574_e0': 100.0,
         'EX_cpd00099_e0': 100.0,
         'EX_cpd00635_e0':100,
         'EX_cpd15574_e0': 100.0,
         'EX_cpd03387_e0': 100.0
}
model1.medium=medium

# %%
biomass_objective = model1.problem.Objective(
    1 * model1.reactions.bio1.flux_expression,
    direction='max')
model1.objective = biomass_objective

model1.optimize()
# Out:
# <Solution 0.000 at 0x7fc9d2e51710>

# %%
#pf
model2.solver = 'optlang-cplex'
medium2 = {
         'EX_cpd00048_e0':100,
         'EX_cpd00009_e0':100,
         'EX_cpd00030_e0': 100,
         'EX_cpd10515_e0': 100,
         'EX_cpd00971_e0': 100,
         'EX_cpd00254_e0': 100,
         'EX_cpd00013_e0': 100,
         'EX_cpd00205_e0': 100,
         'EX_cpd00007_e0': 20,
         'EX_cpd00001_e0': 100,
         'EX_cpd00067_e0': 100,
         'EX_cpd10516_e0': 100.0,
         'EX_cpd00034_e0': 100.0,
         'EX_cpd00063_e0': 100.0,
         #'EX_ni2_e': 100.0,
         #'EX_cu2_e': 100.0,
         #'EX_sel_e': 100.0,
         'EX_cpd00149_e0': 100.0,
         #'EX_mobd_e': 100.0,
         'EX_cpd00099_e0': 100.0,
         #'EX_cbl1_e':100,
         #'EX_tungs_e': 100.0,
         #'EX_slnt_e': 100.0
}
model2.medium=medium2

# %%
biomass_objective = model2.problem.Objective(
    1 * model2.reactions.bio1.flux_expression,
    direction='max')
model2.objective = biomass_objective

model2.optimize()
# Out:
# <Solution 0.000 at 0x7fc9d2f36c10>

# %%
with model1:
    #maltose
    model1.reactions.EX_cpd00179_e0.upper_bound =-1
    model1.reactions.EX_cpd00179_e0.lower_bound =-1
    sol_ecMalt=model1.optimize()
with model1:
    #acetate
    model1.reactions.EX_cpd00029_e0.upper_bound =-1
    model1.reactions.EX_cpd00029_e0.lower_bound =-1
    sol_ecAC=model1.optimize()
with model2:
    #acetate
    model2.reactions.EX_cpd00029_e0.upper_bound =-1
    model2.reactions.EX_cpd00029_e0.lower_bound =-1
    sol_pfAC=model2.optimize()
with model2:
    #4HB
    model2.reactions.EX_cpd00136_e0.upper_bound =-1
    model2.reactions.EX_cpd00136_e0.lower_bound =-1
    sol_pf4HB=model2.optimize()

# %%
sol_ecMalt
# Out:
# <Solution 0.206 at 0x7fc9d2f2b750>

# %%
all_ex=[]
for rxn in model1.reactions:
    if "EX_" in rxn.id:
        all_ex.append(rxn.id)
for rxn in model2.reactions:
    if "EX_" in rxn.id and rxn.id not in all_ex:
        all_ex.append(rxn.id)
all_ex
# Out:
# ['EX_cpd00015_e0',
#  'EX_cpd00126_e0',
#  'EX_cpd00751_e0',
#  'EX_cpd15466_e0',
#  'EX_cpd02150_e0',
#  'EX_cpd03704_e0',
#  'EX_cpd00011_e0',
#  'EX_cpd04273_e0',
#  'EX_cpd00058_e0',
#  'EX_cpd00680_e0',
#  'EX_cpd15460_e0',
#  'EX_cpd00020_e0',
#  'EX_cpd00722_e0',
#  'EX_cpd00296_e0',
#  'EX_cpd00208_e0',
#  'EX_cpd00276_e0',
#  'EX_cpd00033_e0',
#  'EX_cpd00507_e0',
#  'EX_cpd00035_e0',
#  'EX_cpd00209_e0',
#  'EX_cpd03343_e0',
#  'EX_cpd00811_e0',
#  'EX_cpd00781_e0',
#  'EX_cpd00159_e0',
#  'EX_cpd00080_e0',
#  'EX_cpd03422_e0',
#  'EX_cpd00266_e0',
#  'EX_cpd00450_e0',
#  'EX_cpd08021_e0',
#  'EX_cpd24363_e0',
#  'EX_cpd00137_e0',
#  'EX_cpd01570_e0',
#  'EX_cpd00221_e0',
#  'EX_cpd00359_e0',
#  'EX_cpd00047_e0',
#  'EX_cpd21754_e0',
#  'EX_cpd00150_e0',
#  'EX_cpd01217_e0',
#  'EX_colipap-e_e0',
#  'EX_cpd00659_e0',
#  'EX_cpd00497_e0',
#  'EX_cpd00794_e0',
#  'EX_cpd03977_e0',
#  'EX_cpd00644_e0',
#  'EX_cpd00244_e0',
#  'EX_cpd06201_e0',
#  'EX_cpd10924_e0',
#  'EX_cpd00540_e0',
#  'EX_cpd01572_e0',
#  'EX_cpd03696_e0',
#  'EX_cpd00516_e0',
#  'EX_cpd00207_e0',
#  'EX_cpd00268_e0',
#  'EX_cpd00038_e0',
#  'EX_cpd12843_e0',
#  'EX_cpd15493_e0',
#  'EX_cpd00902_e0',
#  'EX_cpd15483_e0',
#  'EX_cpd04461_e0',
#  'EX_cpd03725_e0',
#  'EX_cpd00307_e0',
#  'EX_cpd00182_e0',
#  'EX_cpd01155_e0',
#  'EX_cpd00042_e0',
#  'EX_cpd01107_e0',
#  'EX_cpd11949_e0',
#  'EX_cpd00480_e0',
#  'EX_cpd00703_e0',
#  'EX_cpd00681_e0',
#  'EX_r1535_e0',
#  'EX_cpd00136_e0',
#  'EX_cpd00965_e0',
#  'EX_cpd11416_c0']

# %%
results=[]
line=["bio","biomas",sol_ecMalt.fluxes["bio1"],sol_ecAC.fluxes["bio1"],sol_pfAC.fluxes["bio1"],sol_pf4HB.fluxes["bio1"]]
results.append(line)
for rxn in all_ex:
    if rxn in model1.reactions:
        name=model1.reactions.get_by_id(rxn).name
        if sol_ecMalt.fluxes[rxn] >0 or sol_ecMalt.fluxes[rxn] <0:
            ecmalt=sol_ecMalt.fluxes[rxn]
        else:
            ecmalt=0
        if sol_ecAC.fluxes[rxn]>0 or sol_ecAC.fluxes[rxn]<0:
            ecac=sol_ecAC.fluxes[rxn]
        else:
            ecac=0
    else:
        ecmalt=0
        ecac=0
    if rxn in model2.reactions:
        name=model2.reactions.get_by_id(rxn).name
        if sol_pfAC.fluxes[rxn]>0 or sol_pfAC.fluxes[rxn]<0:
            pfac=sol_pfAC.fluxes[rxn]
        else:
            pfac=0
        if sol_pf4HB.fluxes[rxn]>0 or sol_pf4HB.fluxes[rxn]<0:
            pf4hb=sol_pf4HB.fluxes[rxn]
        else:
            pf4hb=0
    else:
        pfac=0
        pf4hb=0
    line=[rxn,name,ecmalt,ecac,pfac,pf4hb]
    results.append(line)
results_df=pd.DataFrame(results)
results_df.columns=["rxn","rxn name","ecoli-malt","ecoli-acetate","pf-acetate","pf-4HB"]
results_df
# Out:
#                 rxn                                           rxn name  \
# 0               bio                                             biomas
# 1    EX_cpd00015_e0                                Exchange for FAD_e0
# 2    EX_cpd00126_e0                                Exchange for GMP_e0
# 3    EX_cpd00751_e0                           Exchange for L-Fucose_e0
# 4    EX_cpd15466_e0                     Exchange for fructoselysine_e0
# ..              ...                                                ...
# 352  EX_cpd00681_e0                       Exchange for Choline sulfate
# 353     EX_r1535_e0  Exchange for H+ involved in electron transport...
# 354  EX_cpd00136_e0                     Exchange for 4-Hydroxybenzoate
# 355  EX_cpd00965_e0                                    Exchange for Hg
# 356  EX_cpd11416_c0                                   Sink for Biomass
#
#      ecoli-malt  ecoli-acetate  pf-acetate    pf-4HB
# 0      0.206366       0.045744    0.013228  0.046298
# 1      0.000000       0.000000    0.000000  0.000000
# 2      0.000000       0.000000    0.000000  0.000000
# 3      0.000000       0.000000    0.000000  0.000000
# 4      0.000000       0.000000    0.000000  0.000000
# ..          ...            ...         ...       ...
# 352    0.000000       0.000000    0.000000  0.000000
# 353    0.000000       0.000000    0.000000  0.000000
# 354    0.000000       0.000000    0.000000 -1.000000
# 355    0.000000       0.000000    0.000000  0.000000
# 356    0.000000       0.000000    0.013228  0.046298
#
# [357 rows x 6 columns]

# %%
results_df.set_index(["rxn","rxn name"],inplace=True)

results_df = results_df.loc[(results_df != 0).any(axis=1)]
results_df
results_df.to_csv('PhenotypeStoichiometry.csv')
