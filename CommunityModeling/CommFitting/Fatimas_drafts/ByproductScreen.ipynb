# %%
import cobra
from cobra import Model, Reaction, Metabolite
import pandas as pd
import cplex
import optlang
import math
import json
import sys
import os
import cProfile
from optlang.symbolics import Zero, add
import cobra.util.solver as sutil
from cobra.flux_analysis.parsimonious import pfba
from IPython.core.display import HTML
from configparser import ConfigParser
config = ConfigParser()
os.chdir('/Users/chenry/code/ProjectNotebooks/SynBioSFA')
config.read("config.cfg")
paths = config.get("script", "syspaths").split(";")
for path in paths:
    sys.path.append(path)
from modelseedpy import ElementUptakePkg, SimpleThermoPkg, ReactionUsePkg, BilevelPkg

# %%
model= cobra.io.read_sbml_model("iML1515.xml")
model.solver = 'optlang-cplex'
medium = {'EX_malt_e':10,
         'EX_so4_e':100,
         'EX_pi_e':100,
         'EX_mn2_e': 100,
         'EX_fe2_e': 100,
         'EX_na1_e': 100,
         'EX_mg2_e': 100,
         'EX_nh4_e': 100,
         'EX_k_e': 100,
         'EX_o2_e': 20,
         'EX_h2o_e': 100,
         'EX_h_e': 100,
         'EX_fe3_e': 100.0,
         'EX_zn2_e': 100.0,
         'EX_ca2_e': 100.0,
         'EX_ni2_e': 100.0,
         'EX_cu2_e': 100.0,
         'EX_sel_e': 100.0,
         'EX_cobalt2_e': 100.0,
         'EX_mobd_e': 100.0,
         'EX_cl_e': 100.0,
         'EX_cbl1_e':100,
         'EX_tungs_e': 100.0,
         'EX_slnt_e': 100.0
}
model.medium=medium

biomass_objective = model.problem.Objective(
    1 * model.reactions.BIOMASS_Ec_iML1515_WT_75p37M.flux_expression,
    direction='max')
model.objective = biomass_objective

sol=model.optimize()
model.summary()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead tr th {
#         text-align: left;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th></th>
#       <th colspan="2" halign="left">IN_FLUXES</th>
#       <th colspan="2" halign="left">OUT_FLUXES</th>
#       <th colspan="2" halign="left">OBJECTIVES</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th>ID</th>
#       <th>FLUX</th>
#       <th>ID</th>
#       <th>FLUX</th>
#       <th>ID</th>
#       <th>FLUX</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>o2_e</td>
#       <td>20.000000</td>
#       <td>h_e</td>
#       <td>50.528303</td>
#       <td>BIOMASS_Ec_iML1515_WT_75p37M</td>
#       <td>1.121915</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>nh4_e</td>
#       <td>11.812733</td>
#       <td>h2o_e</td>
#       <td>31.675001</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>malt_e</td>
#       <td>10.000000</td>
#       <td>ac_e</td>
#       <td>21.020153</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>pi_e</td>
#       <td>1.056430</td>
#       <td>for_e</td>
#       <td>19.529339</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>co2_e</td>
#       <td>12.506563</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
model.reactions.EX_ac_e.knock_out()
sol=model.optimize()
model.summary()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead tr th {
#         text-align: left;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th></th>
#       <th colspan="2" halign="left">IN_FLUXES</th>
#       <th colspan="2" halign="left">OUT_FLUXES</th>
#       <th colspan="2" halign="left">OBJECTIVES</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th>ID</th>
#       <th>FLUX</th>
#       <th>ID</th>
#       <th>FLUX</th>
#       <th>ID</th>
#       <th>FLUX</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>o2_e</td>
#       <td>20.000000</td>
#       <td>h2o_e</td>
#       <td>37.735885</td>
#       <td>BIOMASS_Ec_iML1515_WT_75p37M</td>
#       <td>0.989793</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>nh4_e</td>
#       <td>10.421618</td>
#       <td>h_e</td>
#       <td>27.966078</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>malt_e</td>
#       <td>10.000000</td>
#       <td>co2_e</td>
#       <td>22.002439</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>pi_e</td>
#       <td>0.932020</td>
#       <td>lac__D_e</td>
#       <td>19.159764</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
model.reactions.EX_lac__D_e.knock_out()
sol=model.optimize()
model.summary()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead tr th {
#         text-align: left;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th></th>
#       <th colspan="2" halign="left">IN_FLUXES</th>
#       <th colspan="2" halign="left">OUT_FLUXES</th>
#       <th colspan="2" halign="left">OBJECTIVES</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th>ID</th>
#       <th>FLUX</th>
#       <th>ID</th>
#       <th>FLUX</th>
#       <th>ID</th>
#       <th>FLUX</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>o2_e</td>
#       <td>20.000000</td>
#       <td>co2_e</td>
#       <td>41.162202</td>
#       <td>BIOMASS_Ec_iML1515_WT_75p37M</td>
#       <td>0.989793</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>nh4_e</td>
#       <td>10.421618</td>
#       <td>h2o_e</td>
#       <td>37.735885</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>malt_e</td>
#       <td>10.000000</td>
#       <td>etoh_e</td>
#       <td>19.159764</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>pi_e</td>
#       <td>0.932020</td>
#       <td>h_e</td>
#       <td>8.806314</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
model.reactions.EX_etoh_e.knock_out()
sol=model.optimize()
model.summary()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead tr th {
#         text-align: left;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th></th>
#       <th colspan="2" halign="left">IN_FLUXES</th>
#       <th colspan="2" halign="left">OUT_FLUXES</th>
#       <th colspan="2" halign="left">OBJECTIVES</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th>ID</th>
#       <th>FLUX</th>
#       <th>ID</th>
#       <th>FLUX</th>
#       <th>ID</th>
#       <th>FLUX</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>o2_e</td>
#       <td>20.000000</td>
#       <td>h2o_e</td>
#       <td>51.911709</td>
#       <td>BIOMASS_Ec_iML1515_WT_75p37M</td>
#       <td>0.978568</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>nh4_e</td>
#       <td>10.303425</td>
#       <td>co2_e</td>
#       <td>36.470110</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>malt_e</td>
#       <td>10.000000</td>
#       <td>h_e</td>
#       <td>15.951631</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>pi_e</td>
#       <td>0.921450</td>
#       <td>hxa_e</td>
#       <td>7.245191</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
model.reactions.EX_hxa_e.knock_out()
sol=model.optimize()
model.summary()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead tr th {
#         text-align: left;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th></th>
#       <th colspan="2" halign="left">IN_FLUXES</th>
#       <th colspan="2" halign="left">OUT_FLUXES</th>
#       <th colspan="2" halign="left">OBJECTIVES</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th>ID</th>
#       <th>FLUX</th>
#       <th>ID</th>
#       <th>FLUX</th>
#       <th>ID</th>
#       <th>FLUX</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>o2_e</td>
#       <td>20.000000</td>
#       <td>h2o_e</td>
#       <td>48.881001</td>
#       <td>BIOMASS_Ec_iML1515_WT_75p37M</td>
#       <td>0.971742</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>nh4_e</td>
#       <td>10.231552</td>
#       <td>h_e</td>
#       <td>31.947615</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>malt_e</td>
#       <td>10.000000</td>
#       <td>pyr_e</td>
#       <td>23.301908</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>pi_e</td>
#       <td>0.915022</td>
#       <td>co2_e</td>
#       <td>10.314965</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
model.reactions.EX_pyr_e.knock_out()
sol=model.optimize()
model.summary()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead tr th {
#         text-align: left;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th></th>
#       <th colspan="2" halign="left">IN_FLUXES</th>
#       <th colspan="2" halign="left">OUT_FLUXES</th>
#       <th colspan="2" halign="left">OBJECTIVES</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th>ID</th>
#       <th>FLUX</th>
#       <th>ID</th>
#       <th>FLUX</th>
#       <th>ID</th>
#       <th>FLUX</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>o2_e</td>
#       <td>20.000000</td>
#       <td>h2o_e</td>
#       <td>48.881001</td>
#       <td>BIOMASS_Ec_iML1515_WT_75p37M</td>
#       <td>0.971742</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>nh4_e</td>
#       <td>10.231552</td>
#       <td>co2_e</td>
#       <td>33.616873</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>malt_e</td>
#       <td>10.000000</td>
#       <td>acald_e</td>
#       <td>23.301908</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>pi_e</td>
#       <td>0.915022</td>
#       <td>h_e</td>
#       <td>8.645707</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
model.reactions.EX_acald_e.knock_out()
sol=model.optimize()
model.summary()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead tr th {
#         text-align: left;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th></th>
#       <th colspan="2" halign="left">IN_FLUXES</th>
#       <th colspan="2" halign="left">OUT_FLUXES</th>
#       <th colspan="2" halign="left">OBJECTIVES</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th>ID</th>
#       <th>FLUX</th>
#       <th>ID</th>
#       <th>FLUX</th>
#       <th>ID</th>
#       <th>FLUX</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>nh4_e</td>
#       <td>26.781669</td>
#       <td>h2o_e</td>
#       <td>55.592063</td>
#       <td>BIOMASS_Ec_iML1515_WT_75p37M</td>
#       <td>0.894441</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>o2_e</td>
#       <td>20.000000</td>
#       <td>h_e</td>
#       <td>25.321976</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>malt_e</td>
#       <td>10.000000</td>
#       <td>co2_e</td>
#       <td>24.970692</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>pi_e</td>
#       <td>0.842234</td>
#       <td>ala__L_e</td>
#       <td>15.228970</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>leu__L_e</td>
#       <td>2.107439</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
model.reactions.EX_ala__L_e.knock_out()
sol=model.optimize()
model.summary()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead tr th {
#         text-align: left;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th></th>
#       <th colspan="2" halign="left">IN_FLUXES</th>
#       <th colspan="2" halign="left">OUT_FLUXES</th>
#       <th colspan="2" halign="left">OBJECTIVES</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th>ID</th>
#       <th>FLUX</th>
#       <th>ID</th>
#       <th>FLUX</th>
#       <th>ID</th>
#       <th>FLUX</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>o2_e</td>
#       <td>20.000000</td>
#       <td>h2o_e</td>
#       <td>55.592063</td>
#       <td>BIOMASS_Ec_iML1515_WT_75p37M</td>
#       <td>0.894441</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>nh4_e</td>
#       <td>19.167184</td>
#       <td>co2_e</td>
#       <td>32.585177</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>malt_e</td>
#       <td>10.000000</td>
#       <td>h_e</td>
#       <td>17.707491</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>pi_e</td>
#       <td>0.842234</td>
#       <td>val__L_e</td>
#       <td>7.614485</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>leu__L_e</td>
#       <td>2.107439</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
model.reactions.EX_val__L_e.knock_out()
sol=model.optimize()
model.summary()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead tr th {
#         text-align: left;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th></th>
#       <th colspan="2" halign="left">IN_FLUXES</th>
#       <th colspan="2" halign="left">OUT_FLUXES</th>
#       <th colspan="2" halign="left">OBJECTIVES</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th>ID</th>
#       <th>FLUX</th>
#       <th>ID</th>
#       <th>FLUX</th>
#       <th>ID</th>
#       <th>FLUX</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>o2_e</td>
#       <td>20.000000</td>
#       <td>h2o_e</td>
#       <td>52.484405</td>
#       <td>BIOMASS_Ec_iML1515_WT_75p37M</td>
#       <td>0.890637</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>nh4_e</td>
#       <td>15.487087</td>
#       <td>co2_e</td>
#       <td>28.633191</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>malt_e</td>
#       <td>10.000000</td>
#       <td>h_e</td>
#       <td>23.200170</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>pi_e</td>
#       <td>0.838652</td>
#       <td>leu__L_e</td>
#       <td>6.081997</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>succ_e</td>
#       <td>4.583284</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# </div>
