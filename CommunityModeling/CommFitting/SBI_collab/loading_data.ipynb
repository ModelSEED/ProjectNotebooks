# %%
from pandas import read_csv, set_option
import os

set_option("display.max_columns", None)
set_option("display.max_rows", None)

df = read_csv("SBI_collab/data/SynCOM_R12_3H11_growth_data_averaged.csv")#.drop(columns="Unnamed: \n0", inplace=True)
display(df)
# Out:
#      Unnamed: 0            Time_Date  RelativeTime Organism  \
# 0             1  2020-11-02 07:49:00      0.000000   SynCom
# 1             2  2020-11-02 18:50:00     11.020000   SynCom
# 2             3  2020-11-03 07:45:00     23.930000   SynCom
# 3             4  2020-11-03 17:20:00     33.520000   SynCom
# 4             5  2020-11-04 08:00:00     48.180000   SynCom
# 5             6  2020-11-04 14:15:00     54.430000   SynCom
# 6             7  2020-11-04 14:15:00     54.430000   SynCom
# 7             8  2020-11-04 18:04:00     58.250000   SynCom
# 8             9  2020-11-04 18:04:00     58.250000   SynCom
# 9            10  2020-11-05 08:15:00     72.430000   SynCom
# 10           11  2020-11-05 08:15:00     72.430000   SynCom
# 11           12  2020-11-05 16:50:00     81.020000   SynCom
# 12           13  2020-11-05 16:50:00     81.020000   SynCom
# 13           14  2020-11-06 07:30:00     95.680000   SynCom
# 14           15  2020-11-06 07:30:00     95.680000   SynCom
# ...

# %%
unique_conditions = df["Exp_Description"].unique()
print(len(unique_conditions), unique_conditions)
# Out:
# 22 ['Pre_SynCom_pH_7' 'Post_SynCom_pH_6' 'Post_SynCom_pH_7'
#  'Pre_3H11_Anaerobic_to_aerobic' 'Post_3H11_Anaerobic_to_aerobic'
#  'Pre_3H11_Ni_0' 'Post_3H11_Ni_0' 'Post_3H11_Ni_150' 'Pre_R12_Ni_0'
#  'Post_R12_Ni_0' 'Post_R12_Ni_150' 'Pre_R12_Anaerobic_to_aerobic'
#  'Post_R12_Anaerobic_to_aerobic' 'Pre_SynCom_Ni_0' 'Post_SynCom_Ni_0'
#  'Post_SynCom_Ni_150' 'Pre_3H11_pH_7' 'Pre_R12_pH_7' 'Post_3H11_pH_6'
#  'Post_3H11_pH_7' 'Post_R12_pH_6' 'Post_R12_pH_7']

# %%
[#'Pre_SynCom_pH_7' 'Post_SynCom_pH_6' 'Post_SynCom_pH_7'
 #'Pre_3H11_Anaerobic_to_aerobic' 'Post_3H11_Anaerobic_to_aerobic'
 #'Pre_3H11_Ni_0' 'Post_3H11_Ni_0' 'Post_3H11_Ni_150' 'Pre_R12_Ni_0'
 #'Post_R12_Ni_0' 'Post_R12_Ni_150' 'Pre_R12_Anaerobic_to_aerobic'
 #'Post_R12_Anaerobic_to_aerobic' 'Pre_SynCom_Ni_0' 'Post_SynCom_Ni_0'
 #'Post_SynCom_Ni_150' 'Pre_3H11_pH_7' 'Pre_R12_pH_7' 'Post_3H11_pH_6'
 #'Post_3H11_pH_7' 'Post_R12_pH_6' 'Post_R12_pH_7'
]

# %%
# pH conditions
pre_pH7 = df[df["Exp_Description"] == "Pre_SynCom_pH_7"]
post_pH6 = df[df["Exp_Description"] == "Post_SynCom_pH_6"]
post_pH7 = df[df["Exp_Description"] == "Post_SynCom_pH_7"]

pre_3H11_pH7 = df[df["Exp_Description"] == "Pre_3H11_pH_7"]
post_3H11_pH7 = df[df["Exp_Description"] == "Post_3H11_pH_7"]
post_3H11_pH6 = df[df["Exp_Description"] == "Post_3H11_pH_6"]

pre_R12_pH7 = df[df["Exp_Description"] == "Pre_R12_pH_7"]
post_R12_pH7 = df[df["Exp_Description"] == "Post_R12_pH_7"]
post_R12_pH6 = df[df["Exp_Description"] == "Post_R12_pH_6"]

# Nickel conditions
pre_Ni0 = df[df["Exp_Description"] == "Pre_SynCom_Ni_0"]
post_Ni0 = df[df["Exp_Description"] == "Post_SynCom_Ni_0"]
post_Ni150 = df[df["Exp_Description"] == "Post_SynCom_Ni_150"]

pre_3H11_Ni0 = df[df["Exp_Description"] == "Pre_3H11_Ni_0"]
post_3H11_Ni0 = df[df["Exp_Description"] == "Post_3H11_Ni_0"]
post_3H11_Ni150 = df[df["Exp_Description"] == "Post_3H11_Ni_150"]

pre_R12_Ni0 = df[df["Exp_Description"] == "Pre_R12_Ni_0"]
post_R12_Ni0 = df[df["Exp_Description"] == "Post_R12_Ni_0"]
post_R12_Ni150 = df[df["Exp_Description"] == "Post_R12_Ni_150"]

# Anaerobic conditions
pre_R12_Anaerobic_to_aerobic = df[df["Exp_Description"] == "Pre_R12_Anaerobic_to_aerobic"]
post_R12_Anaerobic_to_aerobic = df[df["Exp_Description"] == "Post_R12_Anaerobic_to_aerobic"]
pre_3H11_Anaerobic_to_aerobic = df[df["Exp_Description"] == "Pre_3H11_Anaerobic_to_aerobic"]
post_3H11_Anaerobic_to_aerobic = df[df["Exp_Description"] == "Post_3H11_Anaerobic_to_aerobic"]
post_1_Anaerobic_to_aerobic = df[df["Exp_Description"] == "Post_3H11_Anaerobic_to_aerobic"]

# %%
display(pre_pH7, post_pH6, post_pH7)
display(pre_R12_Anaerobic_to_aerobic, post_3H11_Anaerobic_to_aerobic)
# Out:
#    Unnamed: 0            Time_Date  RelativeTime Organism Experiment Transfer  \
# 0           1  2020-11-02 07:49:00          0.00   SynCom   pH_Shift      Pre
# 1           2  2020-11-02 18:50:00         11.02   SynCom   pH_Shift      Pre
# 2           3  2020-11-03 07:45:00         23.93   SynCom   pH_Shift      Pre
# 3           4  2020-11-03 17:20:00         33.52   SynCom   pH_Shift      Pre
# 4           5  2020-11-04 08:00:00         48.18   SynCom   pH_Shift      Pre
#
#    Exp_Description  OD_length  pH_length  DO_Percent_length  NO3_mM_length  \
# 0  Pre_SynCom_pH_7         36         36                 36             36
# 1  Pre_SynCom_pH_7         36         36                 36             36
# 2  Pre_SynCom_pH_7         36         36                 36             36
# 3  Pre_SynCom_pH_7         36         36                 36             36
# 4  Pre_SynCom_pH_7         36         36                 36             36
#
# ...
