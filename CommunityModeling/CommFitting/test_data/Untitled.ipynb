# %%
def _michaelis_menten(conc, vmax, km):
    return (conc*vmax)/(km+conc)

# %%
from numpy import linspace, logspace
from pandas import DataFrame
from matplotlib import pyplot
import IPython
# %matplotlib notebook

# define a dataset for an arbitrary circumstance
vmax = 0.4
km = 0.1
data1 = DataFrame()
data1["concentrations"] = logspace(1, 0.03, 100)
data1["growth rates"] = [_michaelis_menten(conc, vmax, km) for conc in data1["concentrations"]]
# render the developed data
fig, ax = pyplot.subplots(dpi=400)
ax.plot(data1.index, data1["concentrations"])
ax.plot(data1.index, data1["growth rates"])
fig.show()

# define a dataset for an arbitrary circumstance #2
vmax = 1
km = 2
data2 = DataFrame()
data2["concentrations"] = logspace(1, 0.1, 100)
data2["growth rates"] = [_michaelis_menten(conc, vmax, km) for conc in data2["concentrations"]]
# render the developed data
fig, ax = pyplot.subplots(dpi=400)
ax.plot(data2.index, data2["concentrations"])
ax.plot(data2.index, data2["growth rates"])
fig.show()
# Out:
# C:\Users\Andrew Freiburger\AppData\Local\Temp\ipykernel_76260\1788404821.py:17: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# C:\Users\Andrew Freiburger\AppData\Local\Temp\ipykernel_76260\1788404821.py:29: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
display(data1)
display(data2)
# Out:
#     concentrations  growth rates
# 0        10.000000      0.396040
# 1         9.776919      0.395950
# 2         9.558815      0.395859
# 3         9.345576      0.395765
# 4         9.137094      0.395670
# ..             ...           ...
# 95        1.172713      0.368571
# 96        1.146552      0.367911
# 97        1.120975      0.367239
# 98        1.095968      0.366554
# 99        1.071519      0.365856
#
# [100 rows x 2 columns]
#     concentrations  growth rates
# 0        10.000000      0.833333
# 1         9.792850      0.830406
# 2         9.589991      0.827437
# 3         9.391334      0.824428
# 4         9.196792      0.821377
# ..             ...           ...
# 95        1.368875      0.406330
# 96        1.340518      0.401291
# 97        1.312749      0.396272
# 98        1.285556      0.391275
# 99        1.258925      0.386301
#
# [100 rows x 2 columns]
