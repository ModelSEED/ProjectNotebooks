# %%
from datetime import datetime
import os
# from mscommfitting import MSCommFitting
print(os.chdir('C:/Users/Andrew Freiburger/Documents/Argonne/ProjectNotebooks/CommunityModeling/CommFitting/Ecoli_maltose'))
# %run ../mscommfitting.py
mscommfit2 = MSCommFitting(phenotypes_csv_path = 'PhenotypeStoichiometry.csv', 
                           signal_tsv_paths = {'GFP_pf-ec_4-29-22.txt':'ecoli', 'OD_pf-ec_4-29-22.txt':'OD'},
                           media_conc_path = 'media_conc.csv',
                           carbon_conc_series = {'rows': {
                               'cpd00179': {'B':5, 'C': 5, 'D':5, 'E': 5, 'F': 5, 'G': 5},
                               }},
                           ignore_trials = {'wells': ['C2', 'G3', 'C12']},
                          zipped_contents=True)
print(datetime.today())
mscommfit2.define_problem(parameters={'v':100})
print(datetime.today())
# Out:
# None
# The ['rxn name', 'rxn'] columns were dropped from the phenotypes CSV.
# 2022-06-30 20:43:02.833505
# Done with biomass loop: 0.51015625 min
# Done with metabolites loop: 4.119270833333333 min
# Done with the dbc & diffc loop: 0.7864583333333334 min
# Done with loading the variables, constraints, and objective: 3.40078125 min
# Done exporting the content: 0.5864583333333333 min
# 2022-06-30 20:52:31.246496

# %%
# plot the content for desired trials 
graphs = [
    {
        'trial':'B2',
        'content': 'biomass',
        'species': 'ecoli',
        'phenotype': 'acetate'
    },
    {
        'trial':'B2',
        'content': 'growth',
        'species': 'ecoli',
        'phenotype': 'acetate'
    }   
]

# %time mscommfit2.compute(graphs)
# Out:
# CPU times: total: 1h 32s
# Wall time: 1h 33s
# C:\Users\Andrew Freiburger\AppData\Local\Programs\Python\Python39\lib\zipfile.py:1514: UserWarning: Duplicate name: 'B2_ecoli_acetate_biomass.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)
# C:\Users\Andrew Freiburger\AppData\Local\Programs\Python\Python39\lib\zipfile.py:1514: UserWarning: Duplicate name: 'B2_ecoli_acetate_growth.png'
#   return self._open_to_write(zinfo, force_zip64=force_zip64)

# %%
print(mscommfit2.problem.objective.value)
# Out:
# 40214.536846555144

# %%
from datetime import datetime
from numpy import logspace
import os
# from mscommfitting import MSCommFitting
print(os.chdir('C:/Users/Andrew Freiburger/Documents/Argonne/ProjectNotebooks/CommunityModeling/CommFitting/Ecoli_maltose'))
# %run ../mscommfitting.py
graphs = [
    {
        'trial':'B2',
        'content': 'biomass',
        'species': 'ecoli',
        'phenotype': 'malt'
    },
    {
        'trial':'B2',
        'content': 'growth',
        'species': 'ecoli',
        'phenotype': 'malt'
    }   
]
for v in logspace(2.2, 3, 5):
    mscommfit2 = MSCommFitting(phenotypes_csv_path = 'PhenotypeStoichiometry.csv', 
                               signal_tsv_paths = {'GFP_pf-ec_4-29-22.txt':'ecoli', 'OD_pf-ec_4-29-22.txt':'OD'},
                               media_conc_path = 'media_conc.csv',
                               carbon_conc_series = {'rows': {
                                   'cpd00179': {'B':5, 'C': 5, 'D':5, 'E': 5, 'F': 5, 'G': 5},
                                   }},
                               ignore_trials = {'wells': ['C2', 'G3', 'C12']},
                               ignore_timesteps = [x for x in range(20,167)],
                               unzip_contents=True)
    print(datetime.today())
    mscommfit2.define_problem(parameters={'v':v}, zip_contents=False)
    print(datetime.today())
    # %time mscommfit2.compute(graphs)
    print('growth:', v, 'objective value:', mscommfit2.problem.objective.value, '\n\n\n\n')
# Out:
# None
# The ['rxn name', 'rxn'] columns were dropped from the phenotypes CSV.
# 2022-07-01 20:35:27.986552
# Done with biomass loop: 0.07682291666666667 min
# Done with metabolites loop: 0.45625 min
# Done with the dbc & diffc loop: 0.07526041666666666 min
# Done with loading the variables, constraints, and objective: 0.3723958333333333 min
# Done exporting the content: 0.007291666666666667 min
# 2022-07-01 20:36:27.365670
# ---------------------------------------------------------------------------
# SubOptimalError                           Traceback (most recent call last)
# File <timed eval>:1, in <module>
#
# File ~\Documents\Argonne\ProjectNotebooks\CommunityModeling\CommFitting\mscommfitting.py:399, in MSCommFitting.compute(self, graphs)
#     397     print('The solution is optimal.')
#     398 else:
# --> 399     raise SubOptimalError(f'The solution is sub-optimal, with a {solution} status.')
#
# SubOptimalError: The solution is sub-optimal, with a infeasible status.
# growth: 158.48931924611142 objective value: 57.190502803474985
#
#
#
#
# The ['rxn name', 'rxn'] columns were dropped from the phenotypes CSV.
# 2022-07-01 20:36:55.289872
# Done with biomass loop: 0.07942708333333333 min
# Done with metabolites loop: 0.46458333333333335 min
# Done with the dbc & diffc loop: 0.07473958333333333 min
# Done with loading the variables, constraints, and objective: 0.36015625 min
# Done exporting the content: 0.0078125 min
# 2022-07-01 20:37:54.507741
# ---------------------------------------------------------------------------
# SubOptimalError                           Traceback (most recent call last)
# File <timed eval>:1, in <module>
#
# File ~\Documents\Argonne\ProjectNotebooks\CommunityModeling\CommFitting\mscommfitting.py:399, in MSCommFitting.compute(self, graphs)
#     397     print('The solution is optimal.')
#     398 else:
# --> 399     raise SubOptimalError(f'The solution is sub-optimal, with a {solution} status.')
#
# SubOptimalError: The solution is sub-optimal, with a infeasible status.
# growth: 251.18864315095823 objective value: 31.005227682719866
#
#
#
#
# The ['rxn name', 'rxn'] columns were dropped from the phenotypes CSV.
# 2022-07-01 20:38:25.182689
# Done with biomass loop: 0.0984375 min
# Done with metabolites loop: 0.4671875 min
# Done with the dbc & diffc loop: 0.07447916666666667 min
# Done with loading the variables, constraints, and objective: 0.38567708333333334 min
# Done exporting the content: 0.008072916666666667 min
# 2022-07-01 20:39:27.227724
# ---------------------------------------------------------------------------
# SubOptimalError                           Traceback (most recent call last)
# File <timed eval>:1, in <module>
#
# File ~\Documents\Argonne\ProjectNotebooks\CommunityModeling\CommFitting\mscommfitting.py:399, in MSCommFitting.compute(self, graphs)
#     397     print('The solution is optimal.')
#     398 else:
# --> 399     raise SubOptimalError(f'The solution is sub-optimal, with a {solution} status.')
#
# SubOptimalError: The solution is sub-optimal, with a infeasible status.
# growth: 398.1071705534973 objective value: 19.406081100644126
#
#
#
#
# The ['rxn name', 'rxn'] columns were dropped from the phenotypes CSV.
# 2022-07-01 20:39:57.315591
# Done with biomass loop: 0.06770833333333333 min
# Done with metabolites loop: 0.4903645833333333 min
# Done with the dbc & diffc loop: 0.07526041666666666 min
# Done with loading the variables, constraints, and objective: 0.3890625 min
# Done exporting the content: 0.0078125 min
# 2022-07-01 20:40:59.128962
# ---------------------------------------------------------------------------
# SubOptimalError                           Traceback (most recent call last)
# File <timed eval>:1, in <module>
#
# File ~\Documents\Argonne\ProjectNotebooks\CommunityModeling\CommFitting\mscommfitting.py:399, in MSCommFitting.compute(self, graphs)
#     397     print('The solution is optimal.')
#     398 else:
# --> 399     raise SubOptimalError(f'The solution is sub-optimal, with a {solution} status.')
#
# SubOptimalError: The solution is sub-optimal, with a infeasible status.
# growth: 630.957344480193 objective value: 12.389877885887087
#
#
#
#
# The ['rxn name', 'rxn'] columns were dropped from the phenotypes CSV.
# 2022-07-01 20:41:29.284070
# Done with biomass loop: 0.06666666666666667 min
# Done with metabolites loop: 0.48854166666666665 min
# Done with the dbc & diffc loop: 0.07552083333333333 min
# Done with loading the variables, constraints, and objective: 0.36614583333333334 min
# Done exporting the content: 0.0078125 min
# 2022-07-01 20:42:29.583873
# ---------------------------------------------------------------------------
# SubOptimalError                           Traceback (most recent call last)
# File <timed eval>:1, in <module>
#
# File ~\Documents\Argonne\ProjectNotebooks\CommunityModeling\CommFitting\mscommfitting.py:399, in MSCommFitting.compute(self, graphs)
#     397     print('The solution is optimal.')
#     398 else:
# --> 399     raise SubOptimalError(f'The solution is sub-optimal, with a {solution} status.')
#
# SubOptimalError: The solution is sub-optimal, with a infeasible status.
# growth: 1000.0 objective value: 7.860206517997004

# %%
from datetime import datetime
from pandas import read_csv
import os
# from mscommfitting import MSCommFitting
# os.chdir('C:/Users/Andrew Freiburger/Documents/Argonne/ProjectNotebooks/CommunityModeling/CommFitting/Ecoli_maltose')
# %run ../mscommfitting.py

fluxes_df = read_csv('PhenotypeStoichiometry.csv')
graphs = []
for metabolite in fluxes_df['rxn'].to_list():
    graphs.append({
        'trial':'B5',
        'content': metabolite,
        'species': 'ecoli',
        'phenotype': 'malt'
    })
mscommfit2 = MSCommFitting(phenotypes_csv_path = 'PhenotypeStoichiometry.csv', 
                           signal_tsv_paths = {'RFP_pf-ec_4-29-22.txt':'ecoli', 'OD_pf-ec_4-29-22.txt':'OD'},
                           media_conc_path = 'media_conc.csv',
                           species_abundance_path = 'species_abundances.csv',
                           carbon_conc_series = {'rows': {
                               'cpd00179': {'B':5, 'C': 5, 'D':5, 'E': 5, 'F': 5, 'G': 5},
                               }},
                           ignore_trials = {'wells': ['C2', 'G3', 'C12']},  # 'columns': [6,7,8,9,10,11,12]},
                           # ignore_timesteps = [x for x in range(20,167)],
                           unzip_contents=True)
print(datetime.today())
mscommfit2.define_problem(parameters={
    'v':1500,
    'cvmin': 0.5,
    'bcv': 0.5
    }, zip_contents=True)
print(datetime.today())
# %time mscommfit2.compute(graphs)
print('growth:', 1500, 'objective value:', mscommfit2.problem.objective.value, '\n\n\n\n')
# Out:
# The ['rxn name', 'rxn'] columns were dropped from the phenotypes CSV.
# The ['C2', 'C12', 'G3'] trials were dropped from the ecoli measurements.
# The ['B2', 'B12', 'D2', 'D12', 'E2', 'E12', 'F2', 'F12', 'G2', 'G12'] trials were removed from the ecoli measurements, with their deviation over time being less than the threshold of 2.
# The ['C2', 'C12', 'G3'] trials were dropped from the OD measurements.
# 2022-07-03 14:40:07.180043
# Done with biomass loop: 0.6104166666666667 min
# Done with metabolites loop: 3.525260416666667 min
# Done with the dbc & diffc loop: 0.7010416666666667 min
# Done with loading the variables, constraints, and objective: 3.0182291666666665 min
# Done exporting the content: 0.49583333333333335 min
# 2022-07-03 14:48:30.932723
# C:\Users\Andrew Freiburger\Documents\Argonne\ProjectNotebooks\CommunityModeling\CommFitting\mscommfitting.py:428: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = pyplot.subplots()
# ---------------------------------------------------------------------------
# SubOptimalError                           Traceback (most recent call last)
# File <timed eval>:1, in <module>
#
# File ~\Documents\Argonne\ProjectNotebooks\CommunityModeling\CommFitting\mscommfitting.py:412, in MSCommFitting.compute(self, graphs)
#     410     print('The solution is optimal.')
#     411 else:
# --> 412     raise SubOptimalError(f'The solution is sub-optimal, with a {solution} status.')
#
# SubOptimalError: The solution is sub-optimal, with a infeasible status.
# growth: 1500 objective value: 318.9202031733529
