# %% [markdown]
# # Sans initial+final concentration bounds

# %%
from datetime import datetime
import os
# from mscommfitting import MSCommFitting
print(os.chdir('C:/Users/Andrew Freiburger/Documents/Argonne/ProjectNotebooks/CommunityModeling/CommFitting/Ecoli_maltose'))
# %run ../mscommfitting.py
graphs = [
    {
        'trial':'B2',
        'content': 'biomass',
        'species': 'ecoli',
        'phenotype': 'malt'
    },
    {
        'trial':'B2',
        'content': 'growth',
        'species': 'ecoli',
        'phenotype': 'malt'
    }   
]
mscommfit2 = MSCommFitting(phenotypes_csv_path = 'PhenotypeStoichiometry.csv', 
                           signal_tsv_paths = {'GFP_pf-ec_4-29-22.txt':'ecoli', 'OD_pf-ec_4-29-22.txt':'OD'},
                           media_conc_path = 'media_conc.csv',
                           carbon_conc_series = {'rows': {
                               'cpd00179': {'B':5, 'C': 5, 'D':5, 'E': 5, 'F': 5, 'G': 5},
                               }},
                           ignore_trials = {'wells': ['C2', 'G3', 'C12']},  # 'columns': [6,7,8,9,10,11,12]},
                           ignore_timesteps = [x for x in range(50,166)],
                           unzip_contents=True)
print(datetime.today())
mscommfit2.define_problem(parameters={'v':500}, zip_contents=True)
print(datetime.today())
# %time mscommfit2.compute(graphs)
print('growth:', 500, 'objective value:', mscommfit2.problem.objective.value, '\n\n\n\n')
# Out:
# None
# The ['rxn name', 'rxn'] columns were dropped from the phenotypes CSV.
# 2022-07-01 14:45:01.464364
# Done with biomass loop: 0.5268229166666667 min
# Done with metabolites loop: 4.30625 min
# Done with the dbc & diffc loop: 0.8057291666666667 min
# Done with loading the variables, constraints, and objective: 3.4760416666666667 min
# Done exporting the content: 0.07552083333333333 min
# 2022-07-01 14:54:13.488385
# The solution is optimal.
# CPU times: total: 1.56 s
# Wall time: 1.58 s
# growth: 500 objective value: 0.0

# %% [markdown]
# # With intial+final concentration bounds

# %%
from datetime import datetime
from pandas import read_csv
import os
# from mscommfitting import MSCommFitting
print(os.chdir('C:/Users/Andrew Freiburger/Documents/Argonne/ProjectNotebooks/CommunityModeling/CommFitting/Ecoli_maltose'))
# %run ../mscommfitting.py

fluxes_df = read_csv('PhenotypeStoichiometry.csv')
graphs = []
for metabolite in fluxes_df['rxn'].to_list():
    graphs.append({
        'trial':'B5',
        'content': metabolite,
        'species': 'ecoli',
        'phenotype': 'malt'
    })
mscommfit2 = MSCommFitting(phenotypes_csv_path = 'PhenotypeStoichiometry.csv', 
                           signal_tsv_paths = {'RFP_pf-ec_4-29-22.txt':'ecoli', 'OD_pf-ec_4-29-22.txt':'OD'},
                           media_conc_path = 'media_conc.csv',
                           carbon_conc_series = {'rows': {
                               'cpd00179': {'B':5, 'C': 5, 'D':5, 'E': 5, 'F': 5, 'G': 5},
                               }},
                           ignore_trials = {'wells': ['C2', 'G3', 'C12']},  # 'columns': [6,7,8,9,10,11,12]},
                           # ignore_timesteps = [x for x in range(20,167)],
                           unzip_contents=True)
print(datetime.today())
mscommfit2.define_problem(parameters={
    'v':1500,
    'cvmin': 0.5,
    'bcv': 0.5
    }, zip_contents=True)
print(datetime.today())
# %time mscommfit2.compute(graphs)
print('growth:', 1500, 'objective value:', mscommfit2.problem.objective.value, '\n\n\n\n')
# Out:
# None
# The ['rxn name', 'rxn'] columns were dropped from the phenotypes CSV.
# 11636.0 23472.0
# The B2 trial has been removed, with its deviation over time 0.49573960463531014 being less than the threshold 2.
# 24697.0 24361.0
# The B3 trial has been removed, with its deviation over time 1.0137925372521654 being less than the threshold 2.
# 651.0 819.0
# The B12 trial has been removed, with its deviation over time 0.7948717948717948 being less than the threshold 2.
# 42835.0 23979.0
# The D2 trial has been removed, with its deviation over time 1.786354727052838 being less than the threshold 2.
# 668.0 734.0
# The D12 trial has been removed, with its deviation over time 0.9100817438692098 being less than the threshold 2.
# 617.0 727.0
# The E12 trial has been removed, with its deviation over time 0.8486932599724897 being less than the threshold 2.
# 618.0 753.0
# The F12 trial has been removed, with its deviation over time 0.8207171314741036 being less than the threshold 2.
# 739.0 922.0
# The G12 trial has been removed, with its deviation over time 0.8015184381778742 being less than the threshold 2.
# 2022-07-03 11:18:19.127324
# Done with biomass loop: 0.62109375 min
# Done with metabolites loop: 3.6283854166666667 min
# Done with the dbc & diffc loop: 0.6619791666666667 min
# Done with loading the variables, constraints, and objective: 3.179427083333333 min
# Done exporting the content: 0.5138020833333333 min
# 2022-07-03 11:26:57.892157
# C:\Users\Andrew Freiburger\Documents\Argonne\ProjectNotebooks\CommunityModeling\CommFitting\mscommfitting.py:424: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   pyplot.rcParams['figure.figsize'] = (11, 7)
# ---------------------------------------------------------------------------
# SubOptimalError                           Traceback (most recent call last)
# File <timed eval>:1, in <module>
#
# File ~\Documents\Argonne\ProjectNotebooks\CommunityModeling\CommFitting\mscommfitting.py:408, in compute(self, graphs)
#     405         self.values[trial][basename][time] = value
#     407 if graphs != []:
# --> 408     self.graph(graphs)
#     410 if "optimal" in  solution:
#     411     print('The solution is optimal.')
#
# SubOptimalError: The solution is sub-optimal, with a infeasible status.
# growth: 1500 objective value: 9421.676887185136

# %% [markdown]
# # With final concentration bounds

# %%
from datetime import datetime
import os
# from mscommfitting import MSCommFitting
print(os.chdir('C:/Users/Andrew Freiburger/Documents/Argonne/ProjectNotebooks/CommunityModeling/CommFitting/Ecoli_maltose'))
# %run ../mscommfitting.py
graphs = [
    {
        'trial':'B2',
        'content': 'biomass',
        'species': 'ecoli',
        'phenotype': 'malt'
    },
    {
        'trial':'B2',
        'content': 'growth',
        'species': 'ecoli',
        'phenotype': 'malt'
    }   
]
mscommfit2 = MSCommFitting(phenotypes_csv_path = 'PhenotypeStoichiometry.csv', 
                           signal_tsv_paths = {'GFP_pf-ec_4-29-22.txt':'ecoli', 'OD_pf-ec_4-29-22.txt':'OD'},
                           media_conc_path = 'media_conc.csv',
                           carbon_conc_series = {'rows': {
                               'cpd00179': {'B':5, 'C': 5, 'D':5, 'E': 5, 'F': 5, 'G': 5},
                               }},
                           ignore_trials = {'wells': ['C2', 'G3', 'C12']},  # 'columns': [6,7,8,9,10,11,12]},
                           zipped_contents=True)
print(datetime.today())
mscommfit2.define_problem(parameters={'v':500}, zip_contents=False)
print(datetime.today())
# %time mscommfit2.compute(graphs)
print('growth:', 500, 'objective value:', mscommfit2.problem.objective.value, '\n\n\n\n')
# Out:
# None
# The ['rxn name', 'rxn'] columns were dropped from the phenotypes CSV.
# 2022-07-01 15:03:54.226549
# Done with biomass loop: 0.44947916666666665 min
# Done with metabolites loop: 4.57734375 min
# Done with the dbc & diffc loop: 0.9151041666666667 min
# Done with loading the variables, constraints, and objective: 3.530989583333333 min
# Done exporting the content: 0.07708333333333334 min
# 2022-07-01 15:13:27.656818
# The solution is optimal.
# CPU times: total: 1.56 s
# Wall time: 1.59 s
# growth: 500 objective value: 0.0
